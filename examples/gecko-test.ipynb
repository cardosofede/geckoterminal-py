# %%
import sys
import os

# Add the parent directory of geckoterminal_py to the Python path
sys.path.insert(0, os.path.abspath('..'))
from geckoterminal_py.clients.async_client import GeckoTerminalAsyncClient

# %%
client = GeckoTerminalAsyncClient()
await client.get_networks()
# Out:
#                    id     type               name coingecko_asset_platform_id
# 0                 eth  network           Ethereum                    ethereum
# 1                 bsc  network          BNB Chain         binance-smart-chain
# 2         polygon_pos  network        Polygon POS                 polygon-pos
# 3                avax  network          Avalanche                   avalanche
# 4                movr  network          Moonriver                   moonriver
# ..                ...      ...                ...                         ...
# 95             scroll  network             Scroll                        None
# 96  lightlink-phoenix  network  LightLink Phoenix                        None
# 97            elysium  network            Elysium                        None
# 98                ton  network                TON            the-open-network
# 99               mode  network               Mode                        None
#
# [100 rows x 4 columns]

# %%
await client.get_dexes_by_network(network_id="solana")
# Out:
#              id type            name
# 0       raydium  dex         Raydium
# 1          orca  dex            Orca
# 2  raydium-clmm  dex  Raydium (CLMM)
# 3      fluxbeam  dex        FluxBeam
# 4       meteora  dex         Meteora

# %%
await client.get_top_pools_by_network_dex(network_id="solana", dex_id="orca")
# Out:
#                                                    id  type           name  \
# 0   solana_FpCMFDFGYotvufJ7HrFHsWEiiQCGbkLCtwHiDnh...  pool     SOL / USDC
# 1   solana_Czfq3xZZDmsdGdUyrNLtRhGc47cXcZtLG4crryf...  pool     SOL / USDC
# 2   solana_D6NdKrKNQPmRZCCnG1GqXtF7MMoHB7qR6GU5TkG...  pool     $WIF / SOL
# 3   solana_83v8iPyZihDEjDdY8RdZddyZNyUtXngz69Lgo9K...  pool     SOL / USDC
# 4   solana_AHTTzwf3GmVMJdxWM8v2MSxyjZj8rQR6hyAC3g9...  pool   POPCAT / SOL
# 5   solana_FwewVm8u6tFPGewAyHmWAqad9hmF7mvqxK4mJ7i...  pool     USDT / SOL
# 6   solana_CSP4RmB6kBHkKGkyTnzt9zYYXDA8SbZ5Do5WfZc...  pool      HNT / SOL
# 7   solana_4Ui9QdDNuUaAGqCPcDSp191QrixLzQiLxJ1Gnqv...  pool     JUP / USDC
# 8   solana_6NUiVmsNjsi4AfsMsEiaezsaV9N4N1ZrD4jEnuW...  pool     JLP / USDC
# 9   solana_AhhoxZDmsg2snm85vPjqzYzEYESoKfb4KmTj4Hr...  pool     SOL / USDT
# 10  solana_DkVN7RKTNjSSER5oyurf3vddQU2ZneSCYwXvpEr...  pool      JUP / SOL
# ...

# %%
kamu_address = "FCHgHNQb1NVA5RpYFyxeYBEnpveMXsfRYxxn7ahbpump"
await client.get_top_pools_by_network_token(network_id="solana", token_id=kamu_address)
# Out:
#                                                   id  type         name  \
# 0  solana_D7TW63xruRYS46r29tFLjw26xk1ac45NC1buiyH...  pool   Kamu / SOL
# 1  solana_8CYBHpncwtRBRvGZEDUyU91oTCqTS9RjaSqai8k...  pool  Kamu / $WIF
#
#                                 base_token_price_usd  \
# 0  0.00010210093479813241124856871484181487102075...
# 1  0.00013054700342255725223660366253740093372571...
#
#   base_token_price_native_currency  \
# 0    0.000000723758923320868115896
# 1    0.000000930680725988920051469
#
#                                quote_token_price_usd  \
# 0  141.531895370941509231425650966064375889583072...
# 1  1.45072721263888772607431686771018640357019592...
#
#   quote_token_price_native_currency  \
# 0                               1.0
# 1     0.010342358078495326719905382
#
#                                         address reserve_in_usd  \
# 0  D7TW63xruRYS46r29tFLjw26xk1ac45NC1buiyHDZTda     33761.0674
# 1  8CYBHpncwtRBRvGZEDUyU91oTCqTS9RjaSqai8kfahhp         0.0847
# ...

# %%
await client.get_new_pools_by_network(network_id="solana")
# Out:
#                                                    id  type            name  \
# 0   solana_4ZSNgrSzfwFvUFJRiQm9gwF9VJr6NUzAujU195w...  pool   PIKACHU / SOL
# 1   solana_F9phzy229PUVf1ZK4NqZvci3GYBxfrejg7UaBTb...  pool   an/4dog / SOL
# 2   solana_DD37cLWMU6jDicc8j9GdtLCKo2eNQf7UgYjEXkq...  pool     THIEL / SOL
# 3   solana_qkEXLS3WuwxCZwz33t6YZkvTNzXhXqkVEWq16uX...  pool   an/4dog / SOL
# 4   solana_7M9dsf7NGsndfTpJDjA4sLyw6Hodrw7qCE3jei7...  pool      MLEM / SOL
# 5   solana_HhA5mNiGHJd7kfsx42i45Sqt8dkP39sBJqGTM5z...  pool  HawkTuah / SOL
# 6   solana_419GCNexj1xCkHyRu3BmcAndvF3YNiGWmjtyRvz...  pool     dogue / SOL
# 7   solana_2zR96WZ99h85BVBMAVt1hM6iCTVXtENjue8rR66...  pool     dogue / SOL
# 8   solana_3JdGPULyQ8KVLstHDfncF5ZRFrU4JEgR93jjXS1...  pool         🐧 / SOL
# 9   solana_Cm3yxVdhMUNXnGNjDgrJs7G5jLSjgR4Rfqawpzx...  pool      CBAG / SOL
# 10  solana_2QPREbTzDrZnkA1EaDqCVDSXBLW6jyUraFQuNEg...  pool  r/snoofi / SOL
# ...

# %%
kamu_address = "D7TW63xruRYS46r29tFLjw26xk1ac45NC1buiyHDZTda"
await client.get_ohlcv(network_id="solana", pool_address=kamu_address, timeframe="1m")
# Out:
#       timestamp      open      high       low     close    volume_usd  \
# 0    1723898700  0.000055  0.000064  0.000050  0.000050   7709.710736
# 1    1723898760  0.000050  0.000054  0.000043  0.000051   5752.561773
# 2    1723898820  0.000051  0.000090  0.000037  0.000074  18715.623975
# 3    1723898880  0.000074  0.000132  0.000066  0.000094  39015.686195
# 4    1723898940  0.000094  0.000132  0.000087  0.000102  22447.077053
# ..          ...       ...       ...       ...       ...           ...
# 601  1723935300  0.000126  0.000126  0.000115  0.000115    905.977217
# 602  1723935360  0.000115  0.000115  0.000102  0.000102   1036.653623
# 603  1723935420  0.000102  0.000102  0.000102  0.000102     17.310886
# 604  1723935480  0.000102  0.000104  0.000102  0.000104    164.095282
# 605  1723935540  0.000104  0.000104  0.000101  0.000101    501.389935
#
#                datetime
# 0   2024-08-17 12:45:00
# 1   2024-08-17 12:46:00
# 2   2024-08-17 12:47:00
# 3   2024-08-17 12:48:00
# ...

# %%
await client.get_pool_by_network(network_id="solana", pool_address=kamu_address)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 await client.get_pool_by_network(network_id="solana", pool_address=kamu_address)
#
# AttributeError: 'GeckoTerminalAsyncClient' object has no attribute 'get_pool_by_network'
