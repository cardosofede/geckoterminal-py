# %%
from geckoterminal_py import GeckoTerminalAsyncClient

# %%
client = GeckoTerminalAsyncClient()

# %%
await client.get_networks()
# Out:
#                   id     type              name coingecko_asset_platform_id
# 0                eth  network          Ethereum                    ethereum
# 1                bsc  network         BNB Chain         binance-smart-chain
# 2        polygon_pos  network       Polygon POS                 polygon-pos
# 3               avax  network         Avalanche                   avalanche
# 4               movr  network         Moonriver                   moonriver
# ..               ...      ...               ...                         ...
# 95         shibarium  network         Shibarium                        None
# 96     manta-pacific  network     Manta Pacific               manta-pacific
# 97   sepolia-testnet  network   Sepolia Testnet                        None
# 98  hedera-hashgraph  network  Hedera Hashgraph            hedera-hashgraph
# 99        shimmerevm  network        ShimmerEVM                        None
#
# [100 rows x 4 columns]

# %%
await client.get_dexes_by_network("bsc")
# Out:
#                     id type                  name
# 0       pancakeswap_v2  dex  Pancakeswap V2 (BSC)
# 1            jswap_bsc  dex           Jswap (BSC)
# 2          apeswap_bsc  dex         ApeSwap (BSC)
# 3             mdex_bsc  dex            MDEX (BSC)
# 4               biswap  dex             Biswap V2
# ..                 ...  ...                   ...
# 95  woken-exchange-bsc  dex  Woken Exchange (BSC)
# 96        squadswap-v3  dex          SquadSwap V3
# 97         lif3-v3-bsc  dex         Lif3 V3 (BSC)
# 98         lovely-swap  dex           Lovely Swap
# 99           orion-bsc  dex           Orion (BSC)
#
# [100 rows x 3 columns]

# %%
await client.get_top_pools_by_network("bsc")
# Out:
#                                                 id  type               name  \
# 0   bsc_0x0082792bee5aea77c15c6af53fffee6125540376  pool         MTC / USDT
# 1   bsc_0x172fcd41e0913e95784454622d1c3724f546f849  pool  USDT / WBNB 0.01%
# 2   bsc_0x16b9a82891338f9ba80e2d6970fdda79d1eb0dae  pool        USDT / WBNB
# 3   bsc_0x36696169c63e42cd08ce11f5deebbcebae652050  pool  USDT / WBNB 0.05%
# 4   bsc_0x47a90a2d92a8367a91efa1906bfc8c1e05bf10c4  pool  USDT / WBNB 0.01%
# 5   bsc_0x85faac652b707fdf6907ef726751087f9e0b6687  pool  WBNB / BUSD 0.05%
# 6   bsc_0xa87bcbcfcd0d37e67ba7390b0d7a225b9b346a3c  pool        SZ19 / USDT
# 7   bsc_0xf2688fb5b81049dfb7703ada5e770543770612c4  pool  USDC / WBNB 0.01%
# 8   bsc_0xdb2177fee5b0ebdc7b8038cb70f3964bb6d14143  pool  WBNB / BUSD 0.01%
# 9   bsc_0x247f51881d1e3ae0f759afb801413a6c948ef442  pool  USDT / BTCB 0.01%
# 10  bsc_0x6fe9e9de56356f7edbfcbb29fab7cd69471a4869  pool  USDT / WBNB 0.05%
# ...

# %%
await client.get_top_pools_by_network_dex("bsc", "pancakeswap_v2")
# Out:
#                                                 id  type                name  \
# 0   bsc_0x0082792bee5aea77c15c6af53fffee6125540376  pool          MTC / USDT
# 1   bsc_0x16b9a82891338f9ba80e2d6970fdda79d1eb0dae  pool         USDT / WBNB
# 2   bsc_0xa87bcbcfcd0d37e67ba7390b0d7a225b9b346a3c  pool         SZ19 / USDT
# 3   bsc_0x2a097d8062150e7c94fe3c833f095516e8e6ee49  pool       POPCAT / WBNB
# 4   bsc_0x3f7221929f3aa233451f2afc853e46b69a2cf5b3  pool          NOT / USDT
# 5   bsc_0x86a3b3331e8222ce98c218c7c6118ce0ce530606  pool         OSKS / USDT
# 6   bsc_0x63230caefc0f8220536db18136b83b5098b5acbc  pool          CAT / WBNB
# 7   bsc_0x58f876857a02d6762e0101bb5c46a8c1ed44dc16  pool         WBNB / BUSD
# 8   bsc_0xad5d013a307d6dc3aa2a1c908633a69813c8a282  pool           HB / USDT
# 9   bsc_0x4c7cc204b04f5f3f1891db3f4af89895aec53c26  pool          SUN / USDT
# 10  bsc_0x3009b202f0ce46435a5a669bd8c419bf9edfaacc  pool           BB / USDT
# ...

# %%
await client.get_top_pools_by_network_token("bsc", "0x67009eb16ff64d06b4f782b3c552b924b1d1bb93")
# Out:
#                                                id  type           name  \
# 0  bsc_0x0082792bee5aea77c15c6af53fffee6125540376  pool     MTC / USDT
# 1  bsc_0x2fcd48416dd27abe6c254c8186a6d28cf5a20719  pool  MTC / USDT 1%
# 2  bsc_0x37d50d2ba509ebd3e651ad2e67ec01fba7393141  pool     MTC / WBNB
#
#   base_token_price_usd    base_token_price_native_currency  \
# 0    0.381715803849503                0.000640281435033957
# 1     0.38673440665784  0.00063745425634720975756734069192
# 2    0.328686960331487                0.000557519400352674
#
#   quote_token_price_usd quote_token_price_native_currency  \
# 0     0.999838432558119               0.00168128029718936
# 1      1.00029000271228               0.00168179006579107
# 2      588.041109249501                               1.0
#
#                                       address  \
# 0  0x0082792bee5aea77c15c6af53fffee6125540376
# 1  0x2fcd48416dd27abe6c254c8186a6d28cf5a20719
# 2  0x37d50d2ba509ebd3e651ad2e67ec01fba7393141
#
# ...

# %%
await client.get_new_pools_by_network("bsc")
# Out:
#                                                 id  type  \
# 0   bsc_0xc1c15efc7a43126b47788bb19fd984cf07b9be71  pool
# 1   bsc_0x5b0d1fb697cc6ffd43d78114c4cbd571b85a6383  pool
# 2   bsc_0x752f1e3f153206019db58b82fc71685c8252a3e1  pool
# 3   bsc_0x91a48fb5081dcff0d0d68035b37b19c4b10edc05  pool
# 4   bsc_0xa5840fa55a023a2e3cffd8e0a888d36fbaab065a  pool
# 5   bsc_0xc0c557439eb33b757ddd60219b7f528eec4b4aba  pool
# 6   bsc_0xeaaacfad88935fa7585563e3ff5540dda8e0a7b4  pool
# 7   bsc_0x35e9599f7cde3657bd837aa108a5b6fa0f62a44e  pool
# 8   bsc_0xc0199b62fc3fd7ea1cf7e0103955bb49581a364a  pool
# 9   bsc_0xbfc5f6040e8ef3574013f5cc716cf32351c527f8  pool
# 10  bsc_0x1e47bc6aea9cd2bb9d6dd43dfcaca7a19123b7ef  pool
# 11  bsc_0xbfbb37835b4cfa1f124d146e3f4dc949d3ab7f29  pool
# 12  bsc_0xbf9c583b42019134bf1d3eed18b8724c8e42245a  pool
# 13  bsc_0xbf682b94ee974ad3a96bdf2f69ad6a0c9c16fa95  pool
# 14  bsc_0xe9fa5ffa2642ea7aec37b4a5de40c6ad03f0be33  pool
# ...

# %%
await client.get_new_pools_all_networks()
# Out:
#                                                    id  type              name  \
# 0   solana_g2cRTFhsAZPmsgyDWJchiQq4JWbQ3rJzj8gbSUc...  pool      TOTAL3 / SOL
# 1     base_0x74eb10b8ac533e0335a706737a4ed6c7eed79846  pool        FPS / WETH
# 2   solana_6nquizhKTZ96u1emJLd9WKYjVz2hibQKyx3enVc...  pool         CWP / SOL
# 3     base_0x0bd9e3f08fcf79528321eb44858103a4f635c1f9  pool       SHAH / WETH
# 4   solana_D6vhBaiDrd3uUCmPE1BFxos3gDTmNZveXch9tTa...  pool      total3 / SOL
# 5      eth_0x4d02c28c85d88f59240bab69a2cf8334790f648c  pool       JOHN / WETH
# 6   solana_EezZbnjK9Kb3Zbjpt8vEgYBcZtvGE5fcq7nTo2m...  pool    TRUMPWIF / SOL
# 7     base_0x110cc8660435581c82bd3d4e94d1275adbc5f066  pool        USA / WETH
# 8     base_0x4c238c138601effb3829fad63db91d7ac55d2d0c  pool      MICHI / WETH
# 9      bsc_0xc1c15efc7a43126b47788bb19fd984cf07b9be71  pool     EKITTY / WBNB
# 10     eth_0x1107fd76591c3df70e25ba4ecdeeb71a343cc6d9  pool        GME / WETH
# ...

# %%
await client.get_ohlcv("bsc", "0x0082792bee5aea77c15c6af53fffee6125540376", "1h")
# Out:
#       timestamp      open      high       low     close     volume_usd  \
# 0    1712012400  0.210007  0.211602  0.208993  0.209715    3792.319111
# 1    1712016000  0.209715  0.213702  0.209587  0.211563  155893.672561
# 2    1712019600  0.211563  0.213161  0.208737  0.211263  101356.806456
# 3    1712023200  0.211263  0.213699  0.209070  0.211090   76705.766727
# 4    1712026800  0.211090  0.213115  0.210081  0.212133   68778.655472
# ..          ...       ...       ...       ...       ...            ...
# 995  1715594400  0.381275  0.383335  0.377313  0.381031   51680.241614
# 996  1715598000  0.381031  0.383782  0.377327  0.382002   50341.178523
# 997  1715601600  0.382002  0.383504  0.376398  0.381758   46713.228043
# 998  1715605200  0.381758  0.382955  0.377536  0.380812   57800.143480
# 999  1715608800  0.380812  0.382340  0.378094  0.381375    5205.315723
#
#                datetime
# 0   2024-04-01 23:00:00
# 1   2024-04-02 00:00:00
# 2   2024-04-02 01:00:00
# ...
