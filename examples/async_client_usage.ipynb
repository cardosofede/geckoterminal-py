# %%
from geckoterminal_py import GeckoTerminalAsyncClient

# %%
client = GeckoTerminalAsyncClient()

# %% [markdown]
# # NETWORKS - DEXES

# %%
await client.get_networks()
# Out:
#                id     type           name coingecko_asset_platform_id
# 0             eth  network       Ethereum                    ethereum
# 1             bsc  network      BNB Chain         binance-smart-chain
# 2     polygon_pos  network    Polygon POS                 polygon-pos
# 3            avax  network      Avalanche                   avalanche
# 4            movr  network      Moonriver                   moonriver
# ..            ...      ...            ...                         ...
# 95  defimetachain  network  DefiMetaChain               defichain-evm
# 96       humanode  network       Humanode                    humanode
# 97      mxc-zkevm  network      MXC zkEVM                   moonchain
# 98         zkfair  network         ZKFair                      zkfair
# 99     alveychain  network     AlveyChain                  alveychain
#
# [100 rows x 4 columns]

# %%
await client.get_dexes_by_network("solana")
# Out:
#              id type            name
# 0       raydium  dex         Raydium
# 1          orca  dex            Orca
# 2  raydium-clmm  dex  Raydium (CLMM)
# 3      fluxbeam  dex        FluxBeam
# 4       meteora  dex         Meteora
# 5        dexlab  dex          Dexlab

# %% [markdown]
# # POOLS

# %%
await client.get_trending_pools()
# Out:
#                                                    id  type  \
# 0      bsc_0x6df9adc1837bf37e0b1b943d59a7e50d9678c81b  pool
# 1   solana_36dBaPzBXB7f2HV8xu9ZwqaaaL6uofxcszFh2mp...  pool
# 2      eth_0x52c77b0cb827afbad022e6d6caf2c44452edbc39  pool
# 3      eth_0x318ba85ca49a3b12d3cf9c72cc72b29316971802  pool
# 4   solana_37tHJjDVFZGbq1xqtsx6F19EMGG9zhd6jmgBuvP...  pool
# 5   solana_22WrmyTj8x2TRVQen3fxxi2r4Rn6JDHWoMTpsSm...  pool
# 6   solana_424kbbJyt6VkSn7GeKT9Vh5yetuTR1sbeyoya2n...  pool
# 7   sui-network_0x127b7cf262607a0bc6e1035bed13883d...  pool
# 8   solana_HYpXCaAT9YBu7vYa5BURGprsa23hmvdkqXtSUD5...  pool
# 9      eth_0xe6da0cbaedc5e1d0490ec2cda283b8d7f007319e  pool
# 10  solana_9t1H1uDJ558iMPNkEPSN1fqkpC4XSPQ6cqSf6uE...  pool
# 11  solana_HKprCtGbnh1j8xeQggzWhhVd3kwDUdphqPqDP8v...  pool
# 12     bsc_0xcd730b45b703aa4f351adf0f98267a37fd5054eb  pool
# 13  solana_AxBDdiMK9hRPLMPM7k6nCPC1gRARgXQHNejfP2L...  pool
# 14     eth_0x4e34da137f0b317c633838458e0c923a5e088752  pool
# ...

# %%
await client.get_trending_pools_by_network("solana")
# Out:
#                                                    id  type            name  \
# 0   solana_36dBaPzBXB7f2HV8xu9ZwqaaaL6uofxcszFh2mp...  pool    miharu / SOL
# 1   solana_37tHJjDVFZGbq1xqtsx6F19EMGG9zhd6jmgBuvP...  pool  PEPECHAD / SOL
# 2   solana_22WrmyTj8x2TRVQen3fxxi2r4Rn6JDHWoMTpsSm...  pool   MOODENG / SOL
# 3   solana_424kbbJyt6VkSn7GeKT9Vh5yetuTR1sbeyoya2n...  pool     SIGMA / SOL
# 4   solana_HYpXCaAT9YBu7vYa5BURGprsa23hmvdkqXtSUD5...  pool      mini / SOL
# 5   solana_9t1H1uDJ558iMPNkEPSN1fqkpC4XSPQ6cqSf6uE...  pool       SPX / SOL
# 6   solana_HKprCtGbnh1j8xeQggzWhhVd3kwDUdphqPqDP8v...  pool       USA / SOL
# 7   solana_AxBDdiMK9hRPLMPM7k6nCPC1gRARgXQHNejfP2L...  pool      PENG / SOL
# 8   solana_AB1eu2L1Jr3nfEft85AuD2zGksUbam1Kr8MR3uM...  pool      FWOG / SOL
# 9   solana_GvRdXC19SffBALLc4pUCb84KYsvL8dbiUwNgqBE...  pool     PINGU / SOL
# 10  solana_4xxM4cdb6MEsCxM52xvYqkNbzvdeWWsPDZrBcTq...  pool      GIGA / SOL
# ...

# %%
await client.get_pool_by_network_address("solana", "36dBaPzBXB7f2HV8xu9ZwqaaaL6uofxcszFh2mpu9uhu")
# Out:
#                                                   id  type          name  \
# 0  solana_36dBaPzBXB7f2HV8xu9ZwqaaaL6uofxcszFh2mp...  pool  miharu / SOL
#
#                                 base_token_price_usd  \
# 0  0.00690953706026526159924306940987040702246204...
#
#   base_token_price_native_currency  \
# 0    0.000047394178852395099351608
#
#                                quote_token_price_usd  \
# 0  145.652728743123405566949225983997676762123801...
#
#   quote_token_price_native_currency  \
# 0                               1.0
#
#                                         address reserve_in_usd  \
# 0  36dBaPzBXB7f2HV8xu9ZwqaaaL6uofxcszFh2mpu9uhu    425561.2146
#
#         pool_created_at  ... price_change_percentage_h1  \
# 0  2024-10-07T19:31:24Z  ...                     -16.38
#
#   price_change_percentage_h24 transactions_h1_buys transactions_h1_sells  \
# 0                      -46.21                 1578                  1454
#
# ...

# %%
await client.get_multiple_pools_by_network("solana", ["36dBaPzBXB7f2HV8xu9ZwqaaaL6uofxcszFh2mpu9uhu", "37tHJjDVFZGbq1xqtsx6F19EMGG9zhd6jmgBuvPC82ji"])
# Out:
#                                                   id  type            name  \
# 0  solana_36dBaPzBXB7f2HV8xu9ZwqaaaL6uofxcszFh2mp...  pool    miharu / SOL
# 1  solana_37tHJjDVFZGbq1xqtsx6F19EMGG9zhd6jmgBuvP...  pool  PEPECHAD / SOL
#
#                                 base_token_price_usd  \
# 0  0.00691968431583369647929750207345651592033834...
# 1  0.00047091432417559730557997084875250864876898...
#
#   base_token_price_native_currency  \
# 0    0.000047394178852395099351608
# 1    0.000003285787086141935013924
#
#                                quote_token_price_usd  \
# 0  145.652728743123405566949225983997676762123801...
# 1  145.652728743123405566949225983997676762123801...
#
#   quote_token_price_native_currency  \
# 0                               1.0
# 1                               1.0
#
#                                         address reserve_in_usd  \
# 0  36dBaPzBXB7f2HV8xu9ZwqaaaL6uofxcszFh2mpu9uhu    425561.2146
# ...

# %%
await client.get_top_pools_by_network("solana")
# Out:
#                                                    id  type              name  \
# 0   solana_GvRdXC19SffBALLc4pUCb84KYsvL8dbiUwNgqBE...  pool       PINGU / SOL
# 1   solana_5nTBncU4m2eB6LPhaMu4bhounJW7c1T4cbsbs7w...  pool        QUIL / SOL
# 2   solana_6GCSvWU2r2Lpt5ApfzTG6HDofXr29MDpAByEnLi...  pool        $GDP / SOL
# 3   solana_Dqb7bL7MZkuDgHrZZphRMRViJnepHxf9odx3RRw...  pool      MONKEY / SOL
# 4   solana_GPwuECrv8YiCLDbmyCACJL8KqasKvAfiSj9PAhn...  pool      CRINGE / SOL
# 5   solana_H5YkDQGhBWHnpuZA1KgY5UauNXBbwDsX7SHZEUa...  pool        sDOG / SOL
# 6   solana_G7yDq3c4UCuwSA82NMM7fvQWigUT9u6viyCCJR1...  pool      $glaze / SOL
# 7   solana_2FGrz1avfFahP5hxsZdZv5WuiyKYWyBBmADCsyS...  pool        OOGA / SOL
# 8   solana_4a1giKd24E3t86hyyJ7NeUwjhPZFXrZFyTWrmSV...  pool      GUZUTA / SOL
# 9   solana_4af31NPKPuhuzbMtvJak1duj4XkheK6f38yGfz6...  pool         TWK / SOL
# 10  solana_2ARpyCx9wYSqPJNkqNyWMEhfmX6omRCMV9MStTw...  pool     WILFRED / SOL
# ...

# %%
await client.get_top_pools_by_network_dex("solana", "orca")
# Out:
#                                                    id  type            name  \
# 0   solana_AHTTzwf3GmVMJdxWM8v2MSxyjZj8rQR6hyAC3g9...  pool    POPCAT / SOL
# 1   solana_D6NdKrKNQPmRZCCnG1GqXtF7MMoHB7qR6GU5TkG...  pool      $WIF / SOL
# 2   solana_FpCMFDFGYotvufJ7HrFHsWEiiQCGbkLCtwHiDnh...  pool      SOL / USDC
# 3   solana_83v8iPyZihDEjDdY8RdZddyZNyUtXngz69Lgo9K...  pool      SOL / USDC
# 4   solana_Czfq3xZZDmsdGdUyrNLtRhGc47cXcZtLG4crryf...  pool      SOL / USDC
# 5   solana_FwewVm8u6tFPGewAyHmWAqad9hmF7mvqxK4mJ7i...  pool      USDT / SOL
# 6   solana_6NUiVmsNjsi4AfsMsEiaezsaV9N4N1ZrD4jEnuW...  pool      JLP / USDC
# 7   solana_6a3m2EgFFKfsFuQtP4LJJXPcAe3TQYXNyHUjjZp...  pool       JLP / SOL
# 8   solana_EgcL1dmW1NS94mV5Tukd4VoedGj5qtP3ijuar9Q...  pool  MOODENG / USDC
# 9   solana_4fuUiYxTQ6QCrdSq9ouBYcTM7bqSwYTSyLueGZL...  pool     USDC / USDT
# 10  solana_4E6q7eJE6vBNdquqzYYi5gvzd5MNpwiQKhjbRTR...  pool      $WIF / SOL
# ...

# %%
await client.get_new_pools_by_network("solana")
# Out:
#                                                    id  type  \
# 0   solana_HxEwhSWCU6MUNBFaEkRrzfwKL5H8svDBvCH5dJF...  pool
# 1   solana_5cfqmjSkNGVn7xVH3fhHs7ak9EDbLSSdXfcywwQ...  pool
# 2   solana_BLMeJFWYc25ZLmowdMnkcq5XiT4EqzzoEzyg3T7...  pool
# 3   solana_4g7CkmDQcqjnZugxmmqs7vb9aXGnhwEfxK6LMEr...  pool
# 4   solana_2u9jkQMTViLycJE4gn9VC5UpxvEsU8D1LqbwgyB...  pool
# 5   solana_GQMjC4FWf2gwVp9RQ9WaUpm8QYUCP7WV7Wrw7sg...  pool
# 6   solana_5ZDa9U9qT8uHhoDjajhmaX4Yj6c3ZsSD56PGgVX...  pool
# 7   solana_GWAeK5AxCUKq5dGu5dZXiQm4wqQtPoGb6tyDcKa...  pool
# 8   solana_8yT2TCvK67u6tKXYRNQx51fHWMfCH4YpAvviPdw...  pool
# 9   solana_G4UNxfZ7Pqbxjiz8P44uE6gsDUcdq8wscXT93aE...  pool
# 10  solana_DapE8dJ1ManEGcJQpRznp7d8PnJ2pWb24q4g1mw...  pool
# 11  solana_B2moGyGpw9jGhmhskAHJsjzLJ3w3sx2ei5zhS5k...  pool
# 12  solana_7RdTT4ytm75s6vfjepwo1LZ6qg54XGbyjYzaKHL...  pool
# 13  solana_21jQyfZMfXKNPGLYAwWgKJ7JsqAVU5hAej61vU5...  pool
# 14  solana_7SasoSS1XrfkzBwwvF5MGRT6VHHyX3Dy1PugLrA...  pool
# ...

# %%
await client.get_new_pools_all_networks()
# Out:
#                                                    id  type  \
# 0      bsc_0xc49512a7735213f237833e3889b8bd40c205052b  pool
# 1     base_0xa83a98759fcc4d1223ab418093d8e38274f14548  pool
# 2   sui-network_0x634b0e7aaf47633163d8b915a0e604d4...  pool
# 3   sui-network_0x15185c2678d81f861d5201e08e019586...  pool
# 4   solana_HxEwhSWCU6MUNBFaEkRrzfwKL5H8svDBvCH5dJF...  pool
# 5   polygon_pos_0xceef1965784b34537a8b4189ee3fd22b...  pool
# 6   sui-network_0x3b6ae64edc2354f9ebc8f9ba360c1100...  pool
# 7     base_0xec4d7da53b4c379f4bb805337d23df51a364bc83  pool
# 8   ton_EQANI90rxr-YKJ__Qhi3nYGHqxlfBxxGFUljRwaivG...  pool
# 9   sui-network_0xaf2763566de71f7a3da73db63178188b...  pool
# 10    base_0x1be1893e088fa1b8926d7bb19fe3da8e774ab7ba  pool
# 11  solana_5cfqmjSkNGVn7xVH3fhHs7ak9EDbLSSdXfcywwQ...  pool
# 12  solana_BLMeJFWYc25ZLmowdMnkcq5XiT4EqzzoEzyg3T7...  pool
# 13     eth_0xe4ef6935490509956c25dfd09fa4400039672152  pool
# 14    base_0xd1638ac46024744168d1d3148726233e3e8d3f9c  pool
# ...

# %% [markdown]
# # TOKENS

# %%
await client.get_top_pools_by_network_token("solana", "6tVZVjcppH2BZ9Xj5yFU1Zt34m2rYcyDqqpSeMDZpump")
# Out:
#                                                    id  type              name  \
# 0   solana_36dBaPzBXB7f2HV8xu9ZwqaaaL6uofxcszFh2mp...  pool      miharu / SOL
# 1   solana_9CweCNj5tBswwvkLtvjwTLGEPKVqH8CSPbuxgX6...  pool      miharu / SOL
# 2   solana_E61ecucMQPuniioxGwsRnpuVP5uorvBx12wTk2q...  pool      miharu / SOL
# 3   solana_CuFrry6UGSSgHP8CgypwVyM4oyFMU8KL5wD8miw...  pool      miharu / SOL
# 4   solana_EfRD43buNeTE4KhX14TDDtn2mo6PFSAGmwTBsVP...  pool      miharu / SOL
# 5   solana_VUHMHMJcq9HZpnpfhXPFjJxQaQ4BUVWr1uHRTNs...  pool      miharu / SOL
# 6   solana_4aq9z3nhqFnzvDPESyzFbjHP3mXvYU4acUumpxk...  pool      miharu / SOL
# 7   solana_Dn44wpVhbbwDabZBoArue6ibnJzCN79uMaMbhqi...  pool      miharu / SOL
# 8   solana_Esb1na9ur6SUkBTJNJV6ybLEby3CDWdEByt6dcZ...  pool      miharu / SOL
# 9   solana_5FxpJjk4L5uqpEAiopPzFtGNMNuiYGEBUpomYbw...  pool     miharu / GOAT
# 10  solana_UuXXi79WyuPqA9q5TFxjv5LiB1fFVenvy96PTbY...  pool  MOODENG / miharu
# ...

# %%
await client.get_specific_token_on_network("solana", "6tVZVjcppH2BZ9Xj5yFU1Zt34m2rYcyDqqpSeMDZpump")
# Out:
# {'id': 'solana_6tVZVjcppH2BZ9Xj5yFU1Zt34m2rYcyDqqpSeMDZpump',
#  'type': 'token',
#  'attributes': {'address': '6tVZVjcppH2BZ9Xj5yFU1Zt34m2rYcyDqqpSeMDZpump',
#   'name': 'smiling dolphin',
#   'symbol': 'miharu',
#   'decimals': 6,
#   'image_url': 'https://coin-images.coingecko.com/coins/images/50647/large/miharu.jpg?1728611256',
#   'coingecko_coin_id': 'smiling-dolphin',
#   'total_supply': '999935570345000.0',
#   'price_usd': '0.00695219',
#   'fdv_usd': '6951740',
#   'total_reserve_in_usd': '582677.220268779592549413333724937298005261117518315739844169737469175242297547940222',
#   'volume_usd': {'h24': '22095903.5395384'},
#   'market_cap_usd': None},
#  'relationships': {'top_pools': {'data': [{'id': 'solana_36dBaPzBXB7f2HV8xu9ZwqaaaL6uofxcszFh2mpu9uhu',
#      'type': 'pool'},
#     {'id': 'solana_9CweCNj5tBswwvkLtvjwTLGEPKVqH8CSPbuxgX6oc25r',
#      'type': 'pool'},
#     {'id': 'solana_E61ecucMQPuniioxGwsRnpuVP5uorvBx12wTk2q3rsM2',
#      'type': 'pool'}]}}}

# %%
await client.get_ohlcv("bsc", "0x0082792bee5aea77c15c6af53fffee6125540376", "1h")
# Out:
#       timestamp      open      high       low     close     volume_usd  \
# 0    1724637600  0.003140  0.003189  0.002785  0.002823  462739.282898
# 1    1724641200  0.002823  0.003513  0.002714  0.003462  603980.868791
# 2    1724644800  0.003462  0.003465  0.003214  0.003294  492409.486887
# 3    1724648400  0.003294  0.003309  0.002916  0.002986  355845.997041
# 4    1724652000  0.002986  0.003016  0.002897  0.002943  307706.305963
# ..          ...       ...       ...       ...       ...            ...
# 995  1728651600  0.000956  0.000956  0.000951  0.000955      49.020280
# 996  1728655200  0.000955  0.000955  0.000950  0.000954       1.156515
# 997  1728658800  0.000954  0.000956  0.000948  0.000948     208.938326
# 998  1728662400  0.000948  0.000955  0.000948  0.000955      54.592782
# 999  1728666000  0.000955  0.000958  0.000955  0.000958       1.961027
#
#                datetime
# 0   2024-08-26 02:00:00
# 1   2024-08-26 03:00:00
# 2   2024-08-26 04:00:00
# ...

# %%
await client.get_trades("solana", "6uCLSxJgkrLLesUxCVAWscSrA4XFH41UVTfw1yw2YE6A", "100")
# Out:
#                                                     id   type  block_number  \
# 0    solana_295050563_Wnq2KCmefubxHqVy8T6zUJfQ4zAuL...  trade     295050563
# 1    solana_295050207_4Xas1SaMAdVVLEkpvEWxxArWLPgVX...  trade     295050207
# 2    solana_295050207_3UjmoeLhr3k569UVVsMGtuqKocPuv...  trade     295050207
# 3    solana_295050207_XNKuuqoFPx5THDgiaoZQk5oTj3E4W...  trade     295050207
# 4    solana_295049753_4byjZ9QmhnrxwXfBqbtEE15gD6y1i...  trade     295049753
# ..                                                 ...    ...           ...
# 295  solana_295032046_4YGab8sD3SjABnaC2mYVjZTFHHHzT...  trade     295032046
# 296  solana_295032046_3QkQvHXyfd17G5fgDRmvvFyUz7X9N...  trade     295032046
# 297  solana_295032046_2WnZbKFWqURfRwSbVjJwxxjp1GW9F...  trade     295032046
# 298  solana_295032040_3iZ8s9iMcr31wEVADafQyysozcnTT...  trade     295032040
# 299  solana_295032040_2S49ZUgnDFbMYhkk8xHxgbACYpmzz...  trade     295032040
#
# ...
